# %%
#Loading contents of Seam Carving script file
# %run 'SeamCarving_script.ipynb'

import numpy as np
import matplotlib.pyplot as plt
import cv2
from PIL import Image

def show_image(img, title=''):
    plt.imshow(img)
    plt.title(title)
    plt.show()

def main():
    img_path = 'York.jpg'
    york_img = Image.open(img_path)

    show_image(york_img, 'Original York Image')
    
    carved_york_1 = MySeamCarving(york_img, 1200, 1151)
    show_image(carved_york_1, 'York Image Resized to 1200 x 1151')
    carved_york_1.save("YorkImg_1200x1151.jpg")
    
    carved_york_2 = MySeamCarving(york_img, 1728, 720)
    show_image(carved_york_2, 'York Image Resized to 1728 x 720')
    carved_york_2.save("YorkImg_1728x720.jpg") 
    
#---------------------------------------------------------------Personal Image-----------------------------------------------------------
    lake_img_path = 'Lake.jpg'
    lake_img = Image.open(lake_img_path)    

    show_image(lake_img, 'Original Lake Image')

    carved_lake_3 = MySeamCarving(lake_img, 1200, 1151)
    show_image(carved_lake_3, 'Lake Image Resized to 1200 x 1151')
    carved_lake_3.save("LakeImg_1200x1151.jpg")
    
    carved_lake_4 = MySeamCarving(lake_img, 1728, 720)
    show_image(carved_lake_4, 'Lake Image Resized to 1728 x 720')
    carved_lake_4.save("LakeImg_1728x720.jpg") 


if __name__ == "__main__":
    main()
